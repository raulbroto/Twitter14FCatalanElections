# %%
import tweepy
import json
from pymongo import MongoClient
from collections import Counter
from collections.abc import MutableMapping
import logging
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import community
import seaborn as sns
from fastprogress import master_bar, progress_bar
import time
import re


#Logger
logging.basicConfig(filename='Anàlisi-GetTweetInteractions.log', format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', datefmt='%m/%d/%Y %I:%M:%S %p', level=logging.INFO)
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
ch.setFormatter(formatter)
logging.getLogger().addHandler(ch)

# %%
##############
# PARAMETERS #
##############

client = MongoClient(username='XXX', password='XXX')

DatabaseName = "Hashtags"
TweetCollectionName = "Campanya-Interactions"
UserCollectionName = "Users"

db = client[DatabaseName]
tweetCollection = db[TweetCollectionName]

# %%
###############################################
# GET ACTIVE/PASIVE USER + DROP SIMPLE TWEETS #
###############################################

def load_users(user_collection):
    """Extracts the ObjectID and bot/community tags of users
    
    Keyword arguments:
    user_collection -- MongoDB Users' Collection
    """
    pipeline = [
                {
                    '$project': {
                        '_id': True, 
                        'community': True, 
                        'IS_BOT':True
                    }
                }
            ]
    print("Query", end=" ")
    users = user_collection.aggregate(pipeline, allowDiskUse=True)
    print("OK; List", end=" ")
    users = list(users)
    print("OK; Total users:", len(users))
    return users

tweetCollection = db[TweetCollectionName]

tweets = tweetCollection.find(no_cursor_timeout=True, batch_size=1000000)
users = load_users(db[UserCollectionName])
df_users = pd.DataFrame(users)
df_users = df_users.set_index('_id')

print(df_users)

active_id = 0
passive_id = 0

for result in tweets:
    simple_tweet = False #Initially we consider it false
    active_id = result['user']['id']

    if 'retweeted_status' in result:
        passive_id = result['retweeted_status']['user']['id']
    elif result['is_quote_status']:
        if 'quoted_status' in result:
            passive_id = result['quoted_status']['user']['id']
    elif result['in_reply_to_status_id'] is not None:
        passive_id = result['in_reply_to_user_id']
        #print(result['_id'])
    else:
        simple_tweet = True
    
    if simple_tweet:
        ### DELETE THE TWEET IF IT IS SIMPLE
        try:
            tweetCollection.delete_one({'_id': result['_id']})
        except Exception as e:
            logging.error(e)
            logging.error("Fatal exception deleting document in MongoDB")
    else:
        ### Get Active/Passive community/bot category + update the record
        active_community = df_users.loc[active_id, 'community']
        active_is_bot = df_users.loc[active_id, 'IS_BOT']
        
        try:
            passive_community = df_users.loc[passive_id, 'community']
            passive_is_bot = df_users.loc[passive_id, 'IS_BOT']
        except Exception as e:
            logging.error("Passive Reply user not extracted. ERROR!!!")
            passive_community = "ERROR"
            passive_is_bot = "ERROR"

        try:
            tweetCollection.update_one(
                                        {'_id': result['_id']},
                                        {'$set': 
                                            {
                                                'ACTIVE_community': active_community,
                                                'ACTIVE_IS_BOT': active_is_bot,
                                                'PASSIVE_community': passive_community,
                                                'PASSIVE_IS_BOT': passive_is_bot
                                            }
                                        },
                                        upsert=False,
                                      )
        except Exception as e:
            logging.error(e)
            logging.error("Fatal exception inserting users in MongoDB")
            
        
tweets.close()
# Out:
# Query OK; List OK; Total users: 253716
#                            IS_BOT       community
# _id
# 1353285115422584832           BOT            NONE
# 1269990151                    BOT  JUNTADEM+MEDIA
# 1314198625623433216       UNKNOWN    MEDIA+ALTRES
# 161668113                   HUMAN            NONE
# 346092587                   HUMAN            NONE
# ...                           ...             ...
# 1354919162628464641           BOT            NONE
# 974431032824025088          HUMAN            NONE
# 129636906            UNDETERMINED              CS
# 406416847                   HUMAN             CUP
# 2887077099                    BOT           JXCAT
#
# [253716 rows x 2 columns]
# 2021-12-08 18:23:43,677 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:43,677 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:43,993 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:43,993 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:46,627 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:46,627 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:54,525 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:54,525 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:58,855 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:23:58,855 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,014 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,014 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,874 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,874 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,879 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,879 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,914 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,914 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,934 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,934 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,942 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,942 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,972 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:00,972 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:01,004 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:01,004 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:02,722 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:02,722 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:04,764 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:04,764 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:05,175 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:05,175 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:07,589 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:07,589 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:10,793 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:10,793 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:11,866 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:11,866 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:12,088 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:12,088 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:12,680 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:12,680 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:12,921 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:12,921 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:13,411 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:13,411 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:13,496 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:13,496 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:14,377 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:14,377 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:15,988 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:15,988 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:16,009 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:16,009 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:17,342 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:17,342 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:18,631 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:18,631 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:20,886 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:20,886 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:25,102 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:25,102 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:25,226 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:25,226 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:27,252 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:27,252 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:29,351 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:29,351 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:29,433 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:29,433 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:29,600 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:29,600 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:32,611 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:32,611 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:32,808 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:32,808 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:32,877 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:32,877 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:33,815 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:33,815 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,364 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,364 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,651 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,651 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,761 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,761 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,981 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:35,981 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:36,921 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:36,921 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:37,428 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:37,428 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:38,413 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:38,413 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:39,846 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:39,846 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:41,419 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:41,419 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,040 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,040 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,099 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,099 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,529 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,529 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,569 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,569 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,587 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:42,587 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:44,376 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:44,376 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:44,623 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:44,623 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:44,749 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:44,749 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:48,296 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:48,296 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:49,782 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:49,782 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:49,977 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:49,977 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:50,461 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:50,461 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:50,864 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:50,864 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:55,048 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:55,048 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:55,635 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:55,635 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:56,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:24:56,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:00,986 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:00,986 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:01,110 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:01,110 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:02,326 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:02,326 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:04,640 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:04,640 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:12,767 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:12,767 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:12,960 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:12,960 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:13,131 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:13,131 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:13,804 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:13,804 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:14,386 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:14,386 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:15,506 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:15,506 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:16,374 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:16,374 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:16,429 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:16,429 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:20,993 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:20,993 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:23,270 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:23,270 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:23,491 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:23,491 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:24,924 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:24,924 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:26,436 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:26,436 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:27,825 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:27,825 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:34,694 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:34,694 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:39,507 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:39,507 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:39,520 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:39,520 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:39,807 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:39,807 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:41,862 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:41,862 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:51,176 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:51,176 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:55,673 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:55,673 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:56,606 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:25:56,606 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:01,339 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:01,339 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:07,259 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:07,259 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:07,321 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:07,321 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:07,423 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:07,423 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:11,454 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:11,454 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:21,535 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:21,535 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:26,567 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:26,567 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:29,336 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:29,336 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:32,928 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:32,928 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:33,320 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:33,320 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:41,589 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:41,589 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:49,604 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:49,604 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:54,955 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:54,955 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:58,634 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:26:58,634 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:05,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:05,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:07,272 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:07,272 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:16,865 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:16,865 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:19,362 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:19,362 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:22,418 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:22,418 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:30,398 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:30,398 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:30,777 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:30,777 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:30,877 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:30,877 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:32,385 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:32,385 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:32,738 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:32,738 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:36,116 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:36,116 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:38,789 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:38,789 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:46,202 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:46,202 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:47,187 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:47,187 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:51,207 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:51,207 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:51,681 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:27:51,681 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:04,873 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:04,873 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:11,412 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:11,412 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:21,745 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:21,745 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:28,523 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:28,523 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:34,812 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:34,812 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:35,943 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:35,943 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:41,073 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:41,073 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:41,308 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:41,308 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:46,652 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:46,652 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:47,073 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:47,073 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:50,503 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:28:50,503 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:01,045 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:01,045 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:02,520 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:02,520 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:04,474 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:04,474 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:05,109 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:05,109 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:06,742 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:06,742 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:09,271 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:09,271 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:10,136 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:10,136 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:10,712 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:10,712 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:10,804 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:10,804 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:11,991 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:11,991 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:12,781 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:12,781 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:13,045 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:13,045 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:15,002 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:15,002 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:17,841 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:17,841 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,195 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,195 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,224 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,224 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,442 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,442 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,505 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:18,505 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:19,169 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:19,169 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,341 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,341 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,500 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,500 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,671 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,671 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,686 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,686 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,911 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,911 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,949 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,949 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,999 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:20,999 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,161 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,161 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,181 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,181 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,197 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,197 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,223 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,223 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,259 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,259 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,288 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,288 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,330 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,330 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,355 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,355 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,364 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,364 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,368 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,368 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,377 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,377 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,382 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,382 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,387 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,387 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,393 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,393 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,418 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,418 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,423 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,423 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,444 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,444 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,451 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,451 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,587 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,587 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,592 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,592 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,596 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,596 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,599 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,599 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,603 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,603 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,607 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,607 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,613 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,613 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,618 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,618 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,624 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,624 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,634 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,634 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,641 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,641 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,646 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,646 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,651 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,651 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,656 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,656 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,666 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,666 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,799 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,799 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,808 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,808 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,815 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,815 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,822 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,822 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,829 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,829 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,838 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,838 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,845 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,845 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,854 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,854 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,860 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,860 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,866 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,866 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,871 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,871 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,877 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,877 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,883 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,883 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,898 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,898 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,915 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,915 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,921 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,921 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,933 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,933 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,943 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,943 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,949 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,949 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,953 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,953 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,968 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,968 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,972 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,972 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,984 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:21,984 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:22,079 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:22,079 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:22,331 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:22,331 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:22,536 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:22,536 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,384 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,384 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,390 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,390 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,425 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,425 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,798 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:23,798 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:24,545 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:24,545 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:26,808 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:26,808 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:26,903 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:26,903 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,091 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,402 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,402 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,511 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,511 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,831 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,831 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,904 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:27,904 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:30,868 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:30,868 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:30,887 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:30,887 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:33,006 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:33,006 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:41,203 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:41,203 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:56,835 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:56,835 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:57,188 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:57,188 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:57,298 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:29:57,298 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:02,386 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:02,386 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:11,989 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:11,989 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:12,029 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:12,029 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:13,687 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:13,687 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:13,939 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:13,939 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:14,166 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:14,166 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:19,593 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:19,593 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:19,655 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:19,655 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:20,449 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:20,449 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:20,969 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:20,969 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:25,158 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:25,158 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:26,046 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:26,046 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:27,751 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:27,751 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:39,466 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:39,466 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:43,996 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:43,996 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:44,950 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:44,950 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:45,335 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:45,335 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:46,449 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:46,449 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:47,172 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:47,172 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:47,664 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:47,664 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:48,947 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:48,947 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:48,983 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:48,983 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:50,291 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:50,291 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,030 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,030 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,170 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,170 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,690 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,690 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,925 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:52,925 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:57,031 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:57,031 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:59,605 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:30:59,605 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:00,318 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:00,318 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:02,369 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:02,369 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:02,810 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:02,810 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:06,527 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:06,527 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:10,172 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:10,172 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:10,626 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:10,626 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:21,597 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:21,597 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:24,309 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:24,309 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:28,705 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:28,705 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:29,201 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:29,201 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:32,583 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:32,583 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:32,751 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:32,751 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:32,865 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:32,865 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:33,057 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:33,057 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:34,637 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 18:31:34,637 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# ...
# 2021-12-08 19:20:38,844 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:38,844 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:39,012 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:39,012 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:39,152 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:39,152 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:39,675 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:39,675 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:42,262 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:42,262 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:43,476 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:43,476 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:44,011 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:44,011 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:44,267 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:44,267 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,246 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,246 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,287 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,287 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,831 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,831 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,914 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:47,914 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:53,000 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:53,000 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:55,090 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:55,090 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:55,279 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:55,279 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:55,524 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:55,524 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:56,950 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:56,950 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:57,422 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:57,422 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:57,971 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:57,971 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:58,578 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:20:58,578 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:03,312 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:03,312 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:03,909 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:03,909 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:03,999 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:03,999 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:06,339 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:06,339 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:07,862 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:07,862 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:07,956 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:07,956 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:08,199 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:08,199 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:08,268 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:08,268 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:08,364 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:08,364 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:09,120 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:09,120 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:11,198 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:11,198 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:11,679 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:11,679 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:11,804 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:11,804 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:12,199 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:12,199 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:14,457 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:14,457 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:14,819 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:14,819 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:17,614 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:17,614 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:18,550 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:18,550 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:18,663 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:18,663 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:19,634 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:19,634 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:21,513 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:21,513 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:22,286 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:22,286 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:22,722 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:22,722 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,641 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,641 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,664 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,664 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,698 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,698 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,964 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:25,964 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:28,321 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:28,321 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:29,790 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:29,790 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:30,280 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:30,280 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:32,940 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:32,940 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:35,170 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:35,170 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:36,859 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:36,859 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:39,017 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:39,017 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:39,689 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:39,689 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:40,799 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:40,799 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:41,466 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:41,466 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:46,011 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:46,011 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:46,643 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:46,643 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:46,838 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:46,838 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:47,050 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:47,050 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:47,366 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:47,366 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:51,799 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:51,799 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:51,848 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:51,848 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:52,115 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:52,115 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:54,641 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:54,641 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:55,683 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:55,683 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:56,957 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:56,957 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:57,439 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:57,439 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:58,272 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:21:58,272 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:01,897 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:01,897 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:04,371 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:04,371 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:04,585 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:04,585 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:07,498 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:07,498 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:07,508 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:07,508 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:07,569 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:07,569 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:16,112 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:16,112 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:17,377 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:17,377 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:19,673 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:19,673 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:26,708 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:26,708 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:27,160 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:27,160 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,365 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,365 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,371 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,371 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,380 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,380 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,395 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,395 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,478 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,478 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,503 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,503 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,509 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,509 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,524 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,524 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,533 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,533 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,545 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,545 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,551 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,551 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,565 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,565 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,612 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:28,612 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:29,513 - root - ERROR - Passive Reply user not extracted. ERROR!!!
# 2021-12-08 19:22:29,513 - root - ERROR - Passive Reply user not extracted. ERROR!!!

# %%
#######################################
# EXTRACT DATA INTERACTIONS HUMAN-BOT #
#######################################

def load_tweets(collection):
    """Extracts the tweet bot interaction information
    
    Keyword arguments:
    collection -- MongoDB Tweets' Collection
    """
    pipeline = [
                {
                    '$project': {
                        'ACTIVE_IS_BOT': True,
                        'PASSIVE_IS_BOT': True
                    }
                }, {
                    '$group': {
                        '_id': {'ACTIVE_IS_BOT':'$ACTIVE_IS_BOT', 'PASSIVE_IS_BOT':'$PASSIVE_IS_BOT'}, 
                        'count': {
                            '$sum': 1
                        }
                    }
                }
            ]
    print("Query", end=" ")
    tweets = collection.aggregate(pipeline, allowDiskUse=True)
    print("OK; List", end=" ")
    tweets = list(tweets)
    print("OK; Total combinations:", len(tweets))
    return tweets

tweets = load_tweets(tweetCollection)
tweets_df = pd.DataFrame(tweets)
tweets_df2 = pd.concat([pd.json_normalize(tweets_df['_id']), tweets_df['count']], axis=1)

totalTweets = tweets_df2['count'].sum()
print("TOTAL TWEETS: " + str(totalTweets))

print(tweets_df2.sort_values('count', ascending=False).to_string(index=False))

tweets_df3 = tweets_df2.groupby(['ACTIVE_IS_BOT', 'PASSIVE_IS_BOT']).agg({'count': 'sum'})
tweets_df4 = tweets_df3.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

print(tweets_df4.sort_values('ACTIVE_IS_BOT'))
# Out:
# Query OK; List OK; Total combinations: 20
# TOTAL TWEETS: 1887122
# ACTIVE_IS_BOT PASSIVE_IS_BOT  count
#         HUMAN          HUMAN 631088
#  UNDETERMINED          HUMAN 382475
#         HUMAN   UNDETERMINED 317740
#  UNDETERMINED   UNDETERMINED 262913
#           BOT          HUMAN  78781
#           BOT   UNDETERMINED  64977
#         HUMAN            BOT  32792
#  UNDETERMINED            BOT  29544
#       UNKNOWN          HUMAN  18603
#       UNKNOWN   UNDETERMINED  17756
#           BOT            BOT  13726
#  UNDETERMINED        UNKNOWN  13300
#         HUMAN        UNKNOWN  10892
#           BOT        UNKNOWN   4361
#       UNKNOWN        UNKNOWN   3274
#       UNKNOWN            BOT   2391
#         HUMAN          ERROR   1730
#  UNDETERMINED          ERROR    372
#       UNKNOWN          ERROR    280
#           BOT          ERROR    127
#                                   count
# ACTIVE_IS_BOT PASSIVE_IS_BOT
# BOT           BOT              8.474304
#               ERROR            0.078409
#               HUMAN           48.638654
#               UNDETERMINED    40.116193
#               UNKNOWN          2.692441
# HUMAN         UNDETERMINED    31.958014
#               HUMAN           63.474285
#               UNKNOWN          1.095508
#               BOT              3.298191
#               ERROR            0.174002
# UNDETERMINED  BOT              4.290419
#               ERROR            0.054022
#               HUMAN           55.543534
#               UNDETERMINED    38.180580
#               UNKNOWN          1.931444
# UNKNOWN       UNDETERMINED    41.972390
#               BOT              5.651948
#               ERROR            0.661876
#               HUMAN           43.974565
#               UNKNOWN          7.739221

# %%
##########################################
# EXTRACT DATA INTERACTIONS BY COMMUNITY #
##########################################

def load_tweets(collection):
    """Extracts the tweet community interaction information
    
    Keyword arguments:
    collection -- MongoDB Tweets' Collection
    """
    pipeline = [
                {
                    '$project': {
                        'ACTIVE_community': True,
                        'PASSIVE_community': True
                    }
                }, {
                    '$group': {
                        '_id': {'ACTIVE_community':'$ACTIVE_community', 'PASSIVE_community':'$PASSIVE_community'}, 
                        'count': {
                            '$sum': 1
                        }
                    }
                }
            ]
    print("Query", end=" ")
    tweets = collection.aggregate(pipeline, allowDiskUse=True)
    print("OK; List", end=" ")
    tweets = list(tweets)
    print("OK; Total combinations:", len(tweets))
    return tweets

tweets = load_tweets(tweetCollection)
tweets_df = pd.DataFrame(tweets)
tweets_df2 = pd.concat([pd.json_normalize(tweets_df['_id']), tweets_df['count']], axis=1)

totalTweets = tweets_df2['count'].sum()
print("TOTAL TWEETS: " + str(totalTweets))

print(tweets_df2.sort_values('count', ascending=False).head(20).to_string(index=False))

tweets_df3 = tweets_df2.groupby(['ACTIVE_community', 'PASSIVE_community']).agg({'count': 'sum'})
tweets_df4 = tweets_df3.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

print(tweets_df4.sort_values('ACTIVE_community').to_string())
# Out:
# Query OK; List OK; Total combinations: 151
# TOTAL TWEETS: 1887122
# ACTIVE_community PASSIVE_community  count
#            JXCAT             JXCAT 412664
#              VOX               VOX 386151
#              PSC               PSC 229464
#           COMUNS            COMUNS 128143
#              ERC               ERC 120151
#              CUP               CUP 101395
#             NONE              NONE 100122
#               CS                CS  91866
#               PP                PP  88989
#         JUNTADEM          JUNTADEM  27416
#            JXCAT               CUP  18962
#              CUP             JXCAT  13241
#            JXCAT               ERC  12431
#              VOX                PP   8606
#            MEDIA             MEDIA   8060
#              ERC             JXCAT   7631
#              VOX                CS   6495
#            JXCAT              NONE   5819
#             NONE             JXCAT   5516
#               PP               VOX   5472
#                                                        count
# ACTIVE_community         PASSIVE_community
# COMUNS                   COMUNS                    89.545366
#                          VOX                        0.294890
#                          PSC                        2.816134
#                          PP                         0.211035
#                          MEDIA                      0.392721
#                          JXCAT                      2.162763
#                          NONE                       0.937780
#                          ERROR                      0.041229
#                          ERC                        1.144622
#                          CUP                        2.164160
#                          CS                         0.146048
#                          JUNTADEM                   0.143252
# CS                       JXCAT                      0.489636
#                          VOX                        4.695090
#                          PSC                        1.702115
#                          PP                         1.995317
#                          MEDIA                      0.392870
#                          JUNTADEM                   0.183856
#                          NONE                       0.589305
#                          ERROR                      0.044512
#                          ERC                        0.357067
#                          CUP                        0.357067
#                          CS                        88.895125
#                          COMUNS                     0.297072
#                          INTERNACIONAL(VENEZUELA)   0.000968
# CUP                      VOX                        0.423836
#                          PSC                        1.103559
#                          PP                         0.177457
#                          NONE                       1.184365
#                          MEDIA                      0.413537
#                          JXCAT                     10.489749
#                          JUNTADEM                   0.128339
#                          ERC                        3.316221
#                          CUP                       80.326869
#                          CS                         0.221029
#                          COMUNS                     2.142155
#                          ERROR                      0.072884
# ERC                      MEDIA                      0.217380
#                          VOX                        0.120035
#                          PSC                        0.767784
#                          PP                         0.131014
#                          NONE                       0.863665
#                          JXCAT                      5.585280
#                          CUP                        3.276073
#                          ERROR                      0.025617
#                          ERC                       87.940890
#                          JUNTADEM                   0.043915
#                          CS                         0.168342
#                          COMUNS                     0.860006
# INTERNACIONAL(VENEZUELA) VOX                        0.556690
#                          PSC                        0.055669
#                          PP                         0.055669
#                          NONE                       0.278345
#                          MEDIA                      0.037113
#                          JXCAT                      0.018556
#                          INTERNACIONAL(VENEZUELA)  98.292819
#                          ERROR                      0.593802
#                          CUP                        0.055669
#                          CS                         0.018556
#                          COMUNS                     0.018556
#                          JUNTADEM                   0.018556
# JUNTADEM                 MEDIA                      0.728768
#                          VOX                        3.073905
#                          PSC                        1.074465
#                          PP                         0.766140
#                          NONE                       0.893830
#                          JXCAT                      2.566259
#                          COMUNS                     1.466878
#                          INTERNACIONAL(VENEZUELA)   0.006229
#                          ERROR                      0.887602
#                          ERC                        0.968576
#                          CUP                        1.304930
#                          CS                         0.878258
#                          JUNTADEM                  85.384160
# JXCAT                    MEDIA                      0.257686
#                          VOX                        0.109723
#                          PSC                        0.522977
#                          PP                         0.079305
#                          NONE                       1.264313
#                          JXCAT                     89.660837
#                          COMUNS                     1.085280
#                          ERROR                      0.037371
#                          ERC                        2.700923
#                          CUP                        4.119935
#                          CS                         0.073656
#                          JUNTADEM                   0.087996
# MEDIA                    VOX                        3.777700
#                          PSC                        4.667597
#                          PP                         1.823417
#                          NONE                       1.692549
#                          MEDIA                     70.319316
#                          JXCAT                      4.798464
#                          ERROR                      0.340255
#                          ERC                        1.762345
#                          CUP                        4.493108
#                          CS                         1.805968
#                          COMUNS                     3.742802
#                          JUNTADEM                   0.776479
# NONE                     MEDIA                      0.248421
#                          VOX                        0.580816
#                          PSC                        1.147636
#                          PP                         0.256294
#                          NONE                      87.578944
#                          JXCAT                      4.824968
#                          COMUNS                     1.060163
#                          INTERNACIONAL(VENEZUELA)   0.009622
#                          ERROR                      1.280593
#                          ERC                        1.052291
#                          CUP                        1.566628
#                          CS                         0.267665
#                          JUNTADEM                   0.125960
# PP                       MEDIA                      0.331218
#                          PSC                        1.357696
#                          PP                        88.512801
#                          NONE                       0.382940
#                          VOX                        5.442718
#                          JXCAT                      0.492351
#                          ERC                        0.334202
#                          INTERNACIONAL(VENEZUELA)   0.003979
#                          ERROR                      0.043765
#                          CUP                        0.327239
#                          CS                         2.242933
#                          COMUNS                     0.355090
#                          JUNTADEM                   0.173069
# PSC                      VOX                        0.416638
#                          PSC                       94.005252
#                          NONE                       0.563301
#                          MEDIA                      0.376490
#                          JXCAT                      0.582146
#                          PP                         0.249491
#                          ERROR                      0.037280
#                          ERC                        0.739460
#                          CUP                        0.557565
#                          CS                         0.461702
#                          COMUNS                     1.913993
#                          JUNTADEM                   0.096683
# VOX                      PP                         2.100808
#                          NONE                       0.238739
#                          MEDIA                      0.374220
#                          JXCAT                      0.174050
#                          JUNTADEM                   0.269009
#                          ERC                        0.107408
#                          ERROR                      0.036616
#                          CUP                        0.121322
#                          CS                         1.585492
#                          COMUNS                     0.159892
#                          PSC                        0.561208
#                          INTERNACIONAL(VENEZUELA)   0.008056
#                          VOX                       94.263179

# %%
####################################################
# EXTRACT DATA INTERACTIONS HUMAN-BOT BY COMMUNITY #
####################################################

########### DELETE!!!!
DatabaseName = "StreamingHashtags-FINAL"
TweetCollectionName = "Campanya-Interactions"

db = client[DatabaseName]
########### 

def load_tweets(collection):
    """Extracts the tweet bot and community interaction information
    
    Keyword arguments:
    collection -- MongoDB Tweets' Collection
    """
    pipeline = [
                {
                    '$project': {
                        'ACTIVE_IS_BOT': True,
                        'PASSIVE_IS_BOT': True,
                        'ACTIVE_community': True,
                        'PASSIVE_community': True
                    }
                }, {
                    '$group': {
                        '_id': {'ACTIVE_IS_BOT':'$ACTIVE_IS_BOT', 'PASSIVE_IS_BOT':'$PASSIVE_IS_BOT', 
                                'ACTIVE_community':'$ACTIVE_community', 'PASSIVE_community':'$PASSIVE_community'}, 
                        'count': {
                            '$sum': 1
                        }
                    }
                }
            ]
    print("Query", end=" ")
    tweets = collection.aggregate(pipeline, allowDiskUse=True)
    print("OK; List", end=" ")
    tweets = list(tweets)
    print("OK; Total combinations:", len(tweets))
    return tweets

tweets = load_tweets(db[TweetCollectionName])
tweets_df = pd.DataFrame(tweets)
tweets_df2 = pd.concat([pd.json_normalize(tweets_df['_id']), tweets_df['count']], axis=1)

totalTweets = tweets_df2['count'].sum()
print("TOTAL TWEETS: " + str(totalTweets))

print(tweets_df2.sort_values('count', ascending=False).head(100).to_string(index=False))

tweets_df3 = tweets_df2.groupby(['ACTIVE_community', 'PASSIVE_community', 'ACTIVE_IS_BOT', 'PASSIVE_IS_BOT']).agg({'count': 'sum'})
tweets_df4 = tweets_df3.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

#print(tweets_df4.sort_values('ACTIVE_community').to_string())

print(tweets_df4[tweets_df4['count']>1].sort_values('ACTIVE_community').to_string())
# Out:
# Query OK; List OK; Total combinations: 1660
# TOTAL TWEETS: 1887122
# ACTIVE_IS_BOT PASSIVE_IS_BOT         ACTIVE_community        PASSIVE_community  count
#         HUMAN          HUMAN                    JXCAT                    JXCAT 161050
#  UNDETERMINED          HUMAN                    JXCAT                    JXCAT 108116
#  UNDETERMINED   UNDETERMINED                      VOX                      VOX  79457
#         HUMAN          HUMAN                      VOX                      VOX  74836
#         HUMAN          HUMAN                      PSC                      PSC  74524
#  UNDETERMINED          HUMAN                      VOX                      VOX  71336
#         HUMAN   UNDETERMINED                      VOX                      VOX  59749
#  UNDETERMINED          HUMAN                      PSC                      PSC  55270
#         HUMAN          HUMAN                      CUP                      CUP  52536
#         HUMAN          HUMAN                      ERC                      ERC  51475
#         HUMAN   UNDETERMINED                    JXCAT                    JXCAT  48937
#         HUMAN   UNDETERMINED                      PSC                      PSC  41159
#  UNDETERMINED   UNDETERMINED                    JXCAT                    JXCAT  38786
#         HUMAN          HUMAN                   COMUNS                   COMUNS  38098
#  UNDETERMINED   UNDETERMINED                      PSC                      PSC  36998
#         HUMAN   UNDETERMINED                      ERC                      ERC  35632
#         HUMAN          HUMAN                     NONE                     NONE  31893
#         HUMAN          HUMAN                       CS                       CS  27209
#  UNDETERMINED          HUMAN                   COMUNS                   COMUNS  25945
#         HUMAN          HUMAN                       PP                       PP  23734
#  UNDETERMINED          HUMAN                       PP                       PP  23578
#           BOT          HUMAN                    JXCAT                    JXCAT  23290
#           BOT   UNDETERMINED                      VOX                      VOX  22420
#         HUMAN   UNDETERMINED                   COMUNS                   COMUNS  22310
#  UNDETERMINED   UNDETERMINED                   COMUNS                   COMUNS  20905
#         HUMAN   UNDETERMINED                      CUP                      CUP  20548
#  UNDETERMINED          HUMAN                       CS                       CS  18643
#  UNDETERMINED   UNDETERMINED                       PP                       PP  18247
#           BOT          HUMAN                      VOX                      VOX  15924
#  UNDETERMINED          HUMAN                      CUP                      CUP  15678
#  UNDETERMINED          HUMAN                      ERC                      ERC  15638
#  UNDETERMINED   UNDETERMINED                     NONE                     NONE  15495
#         HUMAN   UNDETERMINED                       CS                       CS  15458
#  UNDETERMINED          HUMAN                     NONE                     NONE  15150
#         HUMAN   UNDETERMINED                       PP                       PP  14090
#         HUMAN   UNDETERMINED                     NONE                     NONE  13736
#  UNDETERMINED   UNDETERMINED                      ERC                      ERC  13003
#  UNDETERMINED   UNDETERMINED                       CS                       CS  12713
#  UNDETERMINED            BOT                      VOX                      VOX  11895
#  UNDETERMINED        UNKNOWN                      VOX                      VOX  10129
#       UNKNOWN   UNDETERMINED                      VOX                      VOX   8916
#           BOT          HUMAN                       CS                       CS   8906
#         HUMAN            BOT                    JXCAT                    JXCAT   8809
#           BOT   UNDETERMINED                    JXCAT                    JXCAT   8605
#           BOT          HUMAN                   COMUNS                   COMUNS   8431
#         HUMAN          HUMAN                    JXCAT                      CUP   8260
#           BOT   UNDETERMINED                     NONE                     NONE   8125
#         HUMAN          HUMAN                 JUNTADEM                 JUNTADEM   8024
#         HUMAN          HUMAN                      CUP                    JXCAT   7287
#  UNDETERMINED   UNDETERMINED                      CUP                      CUP   7236
#         HUMAN            BOT                      VOX                      VOX   7026
#           BOT   UNDETERMINED                   COMUNS                   COMUNS   6887
#  UNDETERMINED            BOT                    JXCAT                    JXCAT   6532
#           BOT          HUMAN                      PSC                      PSC   6523
#       UNKNOWN          HUMAN                      VOX                      VOX   5971
#           BOT   UNDETERMINED                       CS                       CS   5859
#         HUMAN   UNDETERMINED                 JUNTADEM                 JUNTADEM   5710
#         HUMAN        UNKNOWN                      VOX                      VOX   5682
#           BOT            BOT                      VOX                      VOX   5297
#         HUMAN          HUMAN                    MEDIA                    MEDIA   5086
#         HUMAN          HUMAN                    JXCAT                      ERC   4924
#           BOT          HUMAN                     NONE                     NONE   4660
#           BOT   UNDETERMINED                      PSC                      PSC   4508
#         HUMAN   UNDETERMINED                    JXCAT                      CUP   4211
#  UNDETERMINED          HUMAN                 JUNTADEM                 JUNTADEM   4208
#         HUMAN          HUMAN INTERNACIONAL(VENEZUELA) INTERNACIONAL(VENEZUELA)   4066
#         HUMAN          HUMAN                      ERC                    JXCAT   3736
#  UNDETERMINED   UNDETERMINED                 JUNTADEM                 JUNTADEM   3583
#  UNDETERMINED          HUMAN                    JXCAT                      CUP   3575
#           BOT        UNKNOWN                      VOX                      VOX   3420
#           BOT          HUMAN                       PP                       PP   3296
#           BOT   UNDETERMINED                       PP                       PP   3032
#         HUMAN   UNDETERMINED                    JXCAT                      ERC   2899
#         HUMAN          HUMAN                      VOX                       PP   2822
#       UNKNOWN          HUMAN                    JXCAT                    JXCAT   2736
#         HUMAN            BOT                      PSC                      PSC   2666
#         HUMAN          HUMAN                      VOX                       CS   2663
#           BOT            BOT                    JXCAT                    JXCAT   2581
#           BOT            BOT                     NONE                     NONE   2562
#         HUMAN          HUMAN                     NONE                    JXCAT   2522
#       UNKNOWN        UNKNOWN                      VOX                      VOX   2505
#       UNKNOWN   UNDETERMINED                      PSC                      PSC   2471
#  UNDETERMINED            BOT                     NONE                     NONE   2392
#  UNDETERMINED          HUMAN                    JXCAT                      ERC   2350
#  UNDETERMINED          HUMAN                      VOX                       PP   2224
#         HUMAN          HUMAN                      ERC                      CUP   2183
#         HUMAN          HUMAN                      PSC                   COMUNS   2135
#         HUMAN   UNDETERMINED                      CUP                    JXCAT   2101
#         HUMAN          HUMAN                    JXCAT                     NONE   2034
#         HUMAN          HUMAN                       PP                      VOX   2004
#       UNKNOWN          HUMAN                      PSC                      PSC   2001
#         HUMAN          HUMAN                      CUP                      ERC   1896
#         HUMAN          HUMAN                    JXCAT                   COMUNS   1873
#  UNDETERMINED          HUMAN                      VOX                       CS   1865
#           BOT          HUMAN                      CUP                      CUP   1865
#  UNDETERMINED   UNDETERMINED                    JXCAT                      CUP   1783
#         HUMAN          HUMAN                   COMUNS                      PSC   1689
#         HUMAN            BOT                   COMUNS                   COMUNS   1661
#  UNDETERMINED          HUMAN                      CUP                    JXCAT   1639
#  UNDETERMINED            BOT                      PSC                      PSC   1607
# "\ntweets_df3 = tweets_df2.groupby(['ACTIVE_community', 'PASSIVE_community', 'ACTIVE_IS_BOT', 'PASSIVE_IS_BOT']).agg({'count': 'sum'})\ntweets_df4 = tweets_df3.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))\n\nprint(tweets_df4.sort_values('ACTIVE_community').to_string())\n"

# %%
########################
# PREPARE HEATMAP DATA #
########################


COMMUNITIES_LIST = ["VOX", "JXCAT", "CUP", "COMUNS", "PSC", "ERC", "PP", "CS"]

def load_tweets(collection):
    """Extracts the tweet community interaction information
    
    Keyword arguments:
    collection -- MongoDB Tweets' Collection
    """
    pipeline = [
                {
                    '$project': {
                        'ACTIVE_community': True,
                        'PASSIVE_community': True
                    }
                }, {
                    '$group': {
                        '_id': {'ACTIVE_community':'$ACTIVE_community', 'PASSIVE_community':'$PASSIVE_community'}, 
                        'count': {
                            '$sum': 1
                        }
                    }
                }
            ]
    print("Query", end=" ")
    tweets = collection.aggregate(pipeline, allowDiskUse=True)
    print("OK; List", end=" ")
    tweets = list(tweets)
    print("OK; Total combinations:", len(tweets))
    return tweets

tweets = load_tweets(tweetCollection)
tweets_df = pd.DataFrame(tweets)
tweets_df2 = pd.concat([pd.json_normalize(tweets_df['_id']), tweets_df['count']], axis=1)

totalTweets = tweets_df2['count'].sum()
print("TOTAL TWEETS: " + str(totalTweets))

tweets_df3 = tweets_df2[tweets_df2['ACTIVE_community'].isin(COMMUNITIES_LIST)]
tweets_df4 = tweets_df3[tweets_df3['PASSIVE_community'].isin(COMMUNITIES_LIST)]

#print(tweets_df4.sort_values('count', ascending=False).to_string(index=False))

tweets_df5 = tweets_df4.groupby(['ACTIVE_community', 'PASSIVE_community']).agg({'count': 'sum'})
tweets_df_test = tweets_df5.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))

print(tweets_df_test.sort_values('ACTIVE_community').to_string())

#THE RESULTS ARE NOT EXACTLY THE SAME... WE HAVE ELIMINATED SOME RECORDS BEFORE GROUPING AND CALCULATING THE %
# Out:
# Query OK; List OK; Total combinations: 151
# TOTAL TWEETS: 1887122
#                                         count
# ACTIVE_community PASSIVE_community
# COMUNS           COMUNS             90.922830
#                  CS                  0.148294
#                  CUP                 2.197451
#                  ERC                 1.162230
#                  JXCAT               2.196032
#                  PP                  0.214282
#                  PSC                 2.859454
#                  VOX                 0.299427
# CS               VOX                 4.752669
#                  PSC                 1.722990
#                  JXCAT               0.495641
#                  PP                  2.019786
#                  CUP                 0.361446
#                  CS                 89.985307
#                  COMUNS              0.300715
#                  ERC                 0.361446
# CUP              COMUNS              2.181402
#                  CS                  0.225078
#                  CUP                81.798527
#                  ERC                 3.376978
#                  JXCAT              10.681930
#                  PP                  0.180708
#                  PSC                 1.123777
#                  VOX                 0.431601
# ERC              PP                  0.132539
#                  PSC                 0.776721
#                  JXCAT               5.650291
#                  VOX                 0.121432
#                  CUP                 3.314205
#                  CS                  0.170301
#                  COMUNS              0.870016
#                  ERC                88.964496
# JXCAT            COMUNS              1.103458
#                  CS                  0.074889
#                  CUP                 4.188942
#                  ERC                 2.746163
#                  JXCAT              91.162618
#                  PP                  0.080633
#                  PSC                 0.531736
#                  VOX                 0.111561
# PP               VOX                 5.494086
#                  PSC                 1.370509
#                  JXCAT               0.496998
#                  PP                 89.348180
#                  CUP                 0.330328
#                  CS                  2.264102
#                  COMUNS              0.358441
#                  ERC                 0.337356
# PSC              VOX                 0.421160
#                  PSC                95.025593
#                  JXCAT               0.588464
#                  PP                  0.252199
#                  CUP                 0.563617
#                  CS                  0.466713
#                  COMUNS              1.934768
#                  ERC                 0.747486
# VOX              PSC                 0.566457
#                  COMUNS              0.161387
#                  CS                  1.600321
#                  CUP                 0.122457
#                  ERC                 0.108413
#                  JXCAT               0.175678
#                  PP                  2.120457
#                  VOX                95.144830

# %%
tweets_df_test = tweets_df_test.reset_index()  
print(tweets_df_test)
# Out:
#     index ACTIVE_community PASSIVE_community      count
# 0       0           COMUNS            COMUNS  90.922830
# 1       1           COMUNS                CS   0.148294
# 2       2           COMUNS               CUP   2.197451
# 3       3           COMUNS               ERC   1.162230
# 4       4           COMUNS             JXCAT   2.196032
# ..    ...              ...               ...        ...
# 59     59              VOX               ERC   0.108413
# 60     60              VOX             JXCAT   0.175678
# 61     61              VOX                PP   2.120457
# 62     62              VOX               PSC   0.566457
# 63     63              VOX               VOX  95.144830
#
# [64 rows x 4 columns]

# %%
##########################
# PREPARE HEATMAP DATA 2 #
##########################

#print(tweets_df_test.index[0])
#print(tweets_df_test.name)
index_active = COMMUNITIES_LIST
index_passive = COMMUNITIES_LIST

total_index = list(set(index_active+index_passive))

#print(index_active)
#print(index_passive)

total_index_clean = [x for x in total_index if str(x) != 'nan']

final_index = sorted(total_index_clean)

print(final_index)
# Out:
# ['COMUNS', 'CS', 'CUP', 'ERC', 'JXCAT', 'PP', 'PSC', 'VOX']

# %%
matrix = np.zeros((len(final_index),len(final_index)))

for active in final_index:
    for passive in final_index:
        #print(active)
        #print(passive)
        value = tweets_df_test[(tweets_df_test["ACTIVE_community"]==active) & (tweets_df_test["PASSIVE_community"]==passive)]["count"]
        matrix[final_index.index(active)][final_index.index(passive)] = value

print(matrix)
# Out:
# [[9.09228302e+01 1.48294261e-01 2.19745133e+00 1.16222966e+00
#   2.19603224e+00 2.14281660e-01 2.85945394e+00 2.99426690e-01]
#  [3.00715055e-01 8.99853071e+01 3.61445783e-01 3.61445783e-01
#   4.95641101e-01 2.01978646e+00 1.72298952e+00 4.75266921e+00]
#  [2.18140162e+00 2.25078051e-01 8.17985269e+01 3.37697750e+00
#   1.06819300e+01 1.80707826e-01 1.12377679e+00 4.31601281e-01]
#  [8.70015919e-01 1.70300988e-01 3.31420532e+00 8.89644959e+01
#   5.65029062e+00 1.32538595e-01 7.76720595e-01 1.21432009e-01]
#  [1.10345772e+00 7.48893229e-02 4.18894201e+00 2.74616275e+00
#   9.11626181e+01 8.06330467e-02 5.31736284e-01 1.11560791e-01]
#  [3.58440933e-01 2.26410169e+00 3.30327918e-01 3.37356172e-01
#   4.96997932e-01 8.93481797e+01 1.37050945e+00 5.49408623e+00]
#  [1.93476784e+00 4.66713048e-01 5.63617088e-01 7.47486293e-01
#   5.88464278e-01 2.52198976e-01 9.50255926e+01 4.21159867e-01]
#  [1.61387290e-01 1.60032130e+00 1.22457226e-01 1.08412836e-01
#   1.75678073e-01 2.12045652e+00 5.66457069e-01 9.51448297e+01]]

# %%
################
# PLOT HEATMAP #
################

def plot_heatmap(m, x_values, y_values, title, xlabel, ylabel, save_fig=False, label_rotation=None):
    """
        Creates a heatmap image from a numpy matrix.

    :param m: 2-dimensional numpy matrix with values to plot
    :param x_values: list of strings for xticks
    :param y_values: list of strings for yticks
    :param title: string, title of the plot
    :param xlabel: string, label of the x axis
    :param ylabel: string, label of the y axis
    :param save_fig: False / "show" / figname , do not show imatge / show it inline / write it to pdf (figure name)
    :param label_rotation: None / int, whether to rotate x ticks (degrees)
    :return:
    """
    
    fig = plt.figure(figsize=(20, 20))
    ax = fig.add_subplot(1, 1, 1)

    im = ax.imshow(m.transpose(), origin='lower', cmap='Reds', alpha=0.7, aspect='auto')
    #im = ax.imshow(m.transpose(), origin='lower', cmap='jet', alpha=0.7)

    # Colorbar
    cbar = ax.figure.colorbar(im, ax=ax)

    # Loop over data dimensions and create text annotations.
    mt = m.transpose()
    for i in range(len(x_values)):
        for j in range(len(y_values)):
            text = ax.text(j, i, "{:.2f}%".format(mt[i, j]), ha="center", va="center", color="black", alpha=1, fontsize=18)

    # Named ticks
    ax.set_xticks(np.arange(len(x_values)))
    ax.set_yticks(np.arange(len(y_values)))
    ax.set_xticklabels(x_values)
    ax.set_yticklabels(y_values)

    # Axis labels
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

    # Rotate x labels
    if label_rotation:
        plt.xticks(rotation=label_rotation)

    fig.tight_layout()
    plt.title(title)
    
    plt.rcParams.update({'font.size': 24})

    # Output result
    if not save_fig:
        pass
    elif save_fig == "show":
        plt.show()
    else:
        plt.savefig(save_fig + '.pdf', format='pdf', dpi=600)
        plt.close()

        
######INPUT DATA#####

m = matrix
x_values = final_index
y_values = final_index
title = "Community interactions"
xlabel = "Passive"
ylabel = "Active"
save_fig = "show"

plot_heatmap(m, x_values, y_values, title, xlabel, ylabel, save_fig, 60)
